# %%
# -----------------------------------------------------------------------------
#  Proyecto: R.O.V.E.R.
#  Módulo: Sistema de Rastreo Solar (Simulación)
#  Descripción:
#      Este script implementa la simulación completa del panel de rastreo solar
#      utilizado en el sistema R.O.V.E.R., responsable de orientar el panel
#      fotovoltaico hacia la mayor incidencia lumínica disponible.
#
#      El panel incluye dos servomotores (horizontal y vertical) y cuatro
#      sensores LDR distribuidos en la estructura para obtener mediciones de
#      luminosidad en tiempo real. Debido a que el proyecto original utiliza
#      Arduino, esta versión en Python se emplea para simular el algoritmo de
#      seguimiento solar y evaluar su desempeño sin hardware físico.
#
#  Equipo de desarrollo:
#      • Carabeo López Darwin Alberto
#      • Hernández Mendoza Abigail
#      • Hernández Tlapa Emmanuel
#      • Lara Hernández Daniel
#      • Villalva Cervantes Jovany
#
#  Notas:
#      El código está orientado a la evaluación del comportamiento dinámico
#      del sistema, simulando el funcionamiento del panel de alimentación solar
#      del R.O.V.E.R. mediante Programación Orientada a Objetos (POO).
# -----------------------------------------------------------------------------

import random
import time


# =============================================================================
#  Clase ServoController
# =============================================================================
class ServoController:
    """
    Clase que representa un servomotor dentro de la simulación.
    Controla límites, posición actual y desplazamientos incrementales.
    """

    def __init__(self, name, initial_angle, limit_low, limit_high):
        """
        Constructor del servomotor.

        Parámetros
        ----------
        name : str
            Nombre identificador del servomotor.
        initial_angle : int
            Ángulo inicial al arrancar el sistema.
        limit_low : int
            Límite inferior permitido.
        limit_high : int
            Límite superior permitido.
        """
        self.name = name
        self.angle = initial_angle
        self.limit_low = limit_low
        self.limit_high = limit_high

    def begin(self):
        """Imprime la posición inicial del servomotor."""
        print(f"{self.name} iniciado en {self.angle}°")

    def set_angle(self, new_angle):
        """
        Asigna un nuevo ángulo al servomotor asegurando que
        permanezca dentro de los límites definidos.
        """
        if new_angle < self.limit_low:
            new_angle = self.limit_low
        if new_angle > self.limit_high:
            new_angle = self.limit_high
        
        self.angle = new_angle
        print(f"{self.name} movido a {self.angle}°")

    def increment(self, value):
        """
        Cambia el ángulo de forma incremental.

        value > 0  → mueve en sentido positivo  
        value < 0  → mueve en sentido negativo
        """
        self.set_angle(self.angle + value)

    def get_angle(self):
        """Retorna el ángulo actual del servomotor."""
        return self.angle


# =============================================================================
#  Clase LDR (Simulación de Sensor de Luz)
# =============================================================================
class LDR:
    """
    Simula un sensor LDR físico.  
    Devuelve valores aleatorios dentro de un rango razonable para representar
    condiciones de iluminación variables.
    """

    def __init__(self, name):
        self.name = name

    def read(self):
        """
        Simula la lectura de un sensor LDR.

        Retorna un valor entre 100 y 900 para modelar escenarios realistas.
        """
        value = random.randint(100, 900)
        print(f"{self.name}: {value}")
        return value


# =============================================================================
#  Clase SolarTracker (Control Principal del Sistema)
# =============================================================================
class SolarTracker:
    """
    Clase central que controla todo el sistema de rastreo solar.  
    Lee sensores, calcula promedios, ajusta tolerancias y mueve los servos para
    orientar el panel hacia la dirección de mayor iluminación.
    """

    def __init__(self):
        # --- Servomotores ---
        self.horizontal = ServoController("Horizontal", 90, 0, 180)
        self.vertical   = ServoController("Vertical",   120, 90, 180)

        # --- Sensores LDR ---
        self.ldr_lt = LDR("LDR Superior Izquierda")
        self.ldr_rt = LDR("LDR Superior Derecha")
        self.ldr_ld = LDR("LDR Inferior Izquierda")
        self.ldr_rd = LDR("LDR Inferior Derecha")

        # Parámetros dinámicos (tolerancia y tiempo)
        self.tol = 100
        self.dtime = 100  # milisegundos

    def begin(self):
        """Inicializa el sistema de rastreo."""
        print("\n=== Iniciando sistema de rastreo solar ===")
        self.horizontal.begin()
        self.vertical.begin()
        print("===========================================\n")

    def update(self):
        """Ejecuta un ciclo completo de lectura y ajuste del panel."""

        # --- Lectura de LDR ---
        lt = self.ldr_lt.read()
        rt = self.ldr_rt.read()
        ld = self.ldr_ld.read()
        rd = self.ldr_rd.read()

        # --- Promedios de zonas ---
        avt = (lt + rt) // 2  # Superior
        avd = (ld + rd) // 2  # Inferior
        avl = (lt + ld) // 2  # Izquierda
        avr = (rt + rd) // 2  # Derecha

        # Promedio global (simula intensidad ambiental)
        veg = (avt + avd + avl + avr) // 4
        print(f"veg={veg}")

        # --- Ajuste dinámico de parámetros ---
        if 0 < veg < 300:
            # Simulación del mapeo del Arduino (map())
            self.tol = int((veg - 10) * (100 - 5) / (300 - 10) + 5)
            self.dtime = int((veg - 10) * (50 - 100) / (300 - 10) + 100)
        else:
            self.tol = 50
            self.dtime = 50

        print(f"tol={self.tol}, dtime={self.dtime}")

        # --- Diferencias entre zonas ---
        dvert = avt - avd
        dhoriz = avl - avr

        # --- Control del eje vertical ---
        if abs(dvert) > self.tol:
            if avt > avd:
                self.vertical.increment(+1)
            else:
                self.vertical.increment(-1)

        # --- Control del eje horizontal ---
        if abs(dhoriz) > self.tol:
            if avl < avr:
                self.horizontal.increment(-1)
            else:
                self.horizontal.increment(+1)

        print("\n-----------------------------------\n")
        time.sleep(self.dtime / 1000)  # Conversión a segundos

# %%
# -----------------------------------------------------
#  Ejecución del sistema
# -----------------------------------------------------
tracker = SolarTracker()
tracker.begin()

while True:
    tracker.update()
# Out:
# === Iniciando sistema de rastreo solar ===
# Horizontal iniciado en 90°
# Vertical iniciado en 120°
# ===========================================
#
# LDR Superior Izquierda: 186
# LDR Superior Derecha: 641
# LDR Inferior Izquierda: 776
# LDR Inferior Derecha: 631
# veg=558
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 309
# LDR Superior Derecha: 529
# LDR Inferior Izquierda: 532
# LDR Inferior Derecha: 624
# veg=498
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 88°
#
# -----------------------------------
#
# LDR Superior Izquierda: 440
# LDR Superior Derecha: 717
# LDR Inferior Izquierda: 301
# LDR Inferior Derecha: 248
# veg=426
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 87°
#
# -----------------------------------
#
# LDR Superior Izquierda: 435
# LDR Superior Derecha: 796
# LDR Inferior Izquierda: 757
# LDR Inferior Derecha: 655
# veg=660
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 86°
#
# -----------------------------------
#
# LDR Superior Izquierda: 659
# LDR Superior Derecha: 341
# LDR Inferior Izquierda: 412
# LDR Inferior Derecha: 483
# veg=473
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 87°
#
# -----------------------------------
#
# LDR Superior Izquierda: 324
# LDR Superior Derecha: 331
# LDR Inferior Izquierda: 693
# LDR Inferior Derecha: 163
# veg=377
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 88°
#
# -----------------------------------
#
# LDR Superior Izquierda: 444
# LDR Superior Derecha: 459
# LDR Inferior Izquierda: 631
# LDR Inferior Derecha: 570
# veg=525
# tol=50, dtime=50
# Vertical movido a 117°
#
# -----------------------------------
#
# LDR Superior Izquierda: 463
# LDR Superior Derecha: 348
# LDR Inferior Izquierda: 720
# LDR Inferior Derecha: 700
# veg=557
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 691
# LDR Superior Derecha: 144
# LDR Inferior Izquierda: 312
# LDR Inferior Derecha: 448
# veg=398
# tol=50, dtime=50
# Horizontal movido a 90°
#
# -----------------------------------
#
# LDR Superior Izquierda: 596
# LDR Superior Derecha: 717
# LDR Inferior Izquierda: 100
# LDR Inferior Derecha: 347
# veg=439
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 100
# LDR Superior Derecha: 305
# LDR Inferior Izquierda: 581
# LDR Inferior Derecha: 157
# veg=285
# tol=95, dtime=52
# Vertical movido a 116°
# Horizontal movido a 90°
#
# -----------------------------------
#
# LDR Superior Izquierda: 884
# LDR Superior Derecha: 540
# LDR Inferior Izquierda: 688
# LDR Inferior Derecha: 300
# veg=603
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 91°
#
# -----------------------------------
#
# LDR Superior Izquierda: 666
# LDR Superior Derecha: 491
# LDR Inferior Izquierda: 877
# LDR Inferior Derecha: 283
# veg=579
# tol=50, dtime=50
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 719
# LDR Superior Derecha: 289
# LDR Inferior Izquierda: 700
# LDR Inferior Derecha: 662
# veg=592
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 536
# LDR Superior Derecha: 898
# LDR Inferior Izquierda: 863
# LDR Inferior Derecha: 164
# veg=615
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 767
# LDR Superior Derecha: 680
# LDR Inferior Izquierda: 485
# LDR Inferior Derecha: 386
# veg=579
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 308
# LDR Superior Derecha: 817
# LDR Inferior Izquierda: 818
# LDR Inferior Derecha: 501
# veg=610
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 255
# LDR Superior Derecha: 294
# LDR Inferior Izquierda: 271
# LDR Inferior Derecha: 863
# veg=420
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 766
# LDR Superior Derecha: 716
# LDR Inferior Izquierda: 899
# LDR Inferior Derecha: 130
# veg=627
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 265
# LDR Superior Derecha: 615
# LDR Inferior Izquierda: 701
# LDR Inferior Derecha: 808
# veg=597
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 858
# LDR Superior Derecha: 163
# LDR Inferior Izquierda: 440
# LDR Inferior Derecha: 887
# veg=586
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 752
# LDR Superior Derecha: 100
# LDR Inferior Izquierda: 868
# LDR Inferior Derecha: 689
# veg=602
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 367
# LDR Superior Derecha: 298
# LDR Inferior Izquierda: 608
# LDR Inferior Derecha: 893
# veg=541
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 647
# LDR Superior Derecha: 445
# LDR Inferior Izquierda: 179
# LDR Inferior Derecha: 551
# veg=455
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 346
# LDR Superior Derecha: 258
# LDR Inferior Izquierda: 705
# LDR Inferior Derecha: 360
# veg=417
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 264
# LDR Superior Derecha: 756
# LDR Inferior Izquierda: 172
# LDR Inferior Derecha: 298
# veg=372
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 684
# LDR Superior Derecha: 698
# LDR Inferior Izquierda: 342
# LDR Inferior Derecha: 474
# veg=549
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 602
# LDR Superior Derecha: 248
# LDR Inferior Izquierda: 156
# LDR Inferior Derecha: 207
# veg=303
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 874
# LDR Superior Derecha: 765
# LDR Inferior Izquierda: 755
# LDR Inferior Derecha: 414
# veg=701
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 706
# LDR Superior Derecha: 733
# LDR Inferior Izquierda: 883
# LDR Inferior Derecha: 726
# veg=761
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 214
# LDR Superior Derecha: 798
# LDR Inferior Izquierda: 760
# LDR Inferior Derecha: 490
# veg=565
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 127
# LDR Superior Derecha: 896
# LDR Inferior Izquierda: 775
# LDR Inferior Derecha: 763
# veg=640
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 354
# LDR Superior Derecha: 865
# LDR Inferior Izquierda: 209
# LDR Inferior Derecha: 661
# veg=522
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 125
# LDR Superior Derecha: 348
# LDR Inferior Izquierda: 521
# LDR Inferior Derecha: 685
# veg=419
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 91°
#
# -----------------------------------
#
# LDR Superior Izquierda: 434
# LDR Superior Derecha: 835
# LDR Inferior Izquierda: 208
# LDR Inferior Derecha: 362
# veg=459
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 90°
#
# -----------------------------------
#
# LDR Superior Izquierda: 538
# LDR Superior Derecha: 567
# LDR Inferior Izquierda: 764
# LDR Inferior Derecha: 689
# veg=639
# tol=50, dtime=50
# Vertical movido a 114°
#
# -----------------------------------
#
# LDR Superior Izquierda: 231
# LDR Superior Derecha: 535
# LDR Inferior Izquierda: 483
# LDR Inferior Derecha: 167
# veg=354
# tol=50, dtime=50
# Vertical movido a 115°
#
# -----------------------------------
#
# LDR Superior Izquierda: 217
# LDR Superior Derecha: 646
# LDR Inferior Izquierda: 444
# LDR Inferior Derecha: 424
# veg=432
# tol=50, dtime=50
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 283
# LDR Superior Derecha: 740
# LDR Inferior Izquierda: 330
# LDR Inferior Derecha: 204
# veg=389
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 88°
#
# -----------------------------------
#
# LDR Superior Izquierda: 898
# LDR Superior Derecha: 243
# LDR Inferior Izquierda: 461
# LDR Inferior Derecha: 162
# veg=440
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 343
# LDR Superior Derecha: 706
# LDR Inferior Izquierda: 216
# LDR Inferior Derecha: 445
# veg=427
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 88°
#
# -----------------------------------
#
# LDR Superior Izquierda: 674
# LDR Superior Derecha: 395
# LDR Inferior Izquierda: 181
# LDR Inferior Derecha: 409
# veg=414
# tol=50, dtime=50
# Vertical movido a 119°
#
# -----------------------------------
#
# LDR Superior Izquierda: 750
# LDR Superior Derecha: 119
# LDR Inferior Izquierda: 147
# LDR Inferior Derecha: 579
# veg=398
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 603
# LDR Superior Derecha: 540
# LDR Inferior Izquierda: 396
# LDR Inferior Derecha: 405
# veg=485
# tol=50, dtime=50
# Vertical movido a 121°
#
# -----------------------------------
#
# LDR Superior Izquierda: 480
# LDR Superior Derecha: 685
# LDR Inferior Izquierda: 214
# LDR Inferior Derecha: 777
# veg=538
# tol=50, dtime=50
# Vertical movido a 122°
# Horizontal movido a 88°
#
# -----------------------------------
#
# LDR Superior Izquierda: 883
# LDR Superior Derecha: 643
# LDR Inferior Izquierda: 661
# LDR Inferior Derecha: 213
# veg=600
# tol=50, dtime=50
# Vertical movido a 123°
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 760
# LDR Superior Derecha: 319
# LDR Inferior Izquierda: 461
# LDR Inferior Derecha: 137
# veg=419
# tol=50, dtime=50
# Vertical movido a 124°
# Horizontal movido a 90°
#
# -----------------------------------
#
# LDR Superior Izquierda: 266
# LDR Superior Derecha: 317
# LDR Inferior Izquierda: 821
# LDR Inferior Derecha: 361
# veg=441
# tol=50, dtime=50
# Vertical movido a 123°
# Horizontal movido a 91°
#
# -----------------------------------
#
# LDR Superior Izquierda: 749
# LDR Superior Derecha: 696
# LDR Inferior Izquierda: 822
# LDR Inferior Derecha: 698
# veg=741
# tol=50, dtime=50
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 746
# LDR Superior Derecha: 889
# LDR Inferior Izquierda: 291
# LDR Inferior Derecha: 763
# veg=672
# tol=50, dtime=50
# Vertical movido a 124°
# Horizontal movido a 91°
#
# -----------------------------------
#
# LDR Superior Izquierda: 518
# LDR Superior Derecha: 424
# LDR Inferior Izquierda: 896
# LDR Inferior Derecha: 327
# veg=541
# tol=50, dtime=50
# Vertical movido a 123°
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 844
# LDR Superior Derecha: 525
# LDR Inferior Izquierda: 111
# LDR Inferior Derecha: 526
# veg=501
# tol=50, dtime=50
# Vertical movido a 124°
#
# -----------------------------------
#
# LDR Superior Izquierda: 550
# LDR Superior Derecha: 184
# LDR Inferior Izquierda: 598
# LDR Inferior Derecha: 441
# veg=443
# tol=50, dtime=50
# Vertical movido a 123°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 100
# LDR Superior Derecha: 189
# LDR Inferior Izquierda: 466
# LDR Inferior Derecha: 701
# veg=363
# tol=50, dtime=50
# Vertical movido a 122°
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 450
# LDR Superior Derecha: 136
# LDR Inferior Izquierda: 713
# LDR Inferior Derecha: 612
# veg=477
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 259
# LDR Superior Derecha: 744
# LDR Inferior Izquierda: 437
# LDR Inferior Derecha: 110
# veg=387
# tol=50, dtime=50
# Vertical movido a 122°
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 200
# LDR Superior Derecha: 259
# LDR Inferior Izquierda: 428
# LDR Inferior Derecha: 753
# veg=409
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 91°
#
# -----------------------------------
#
# LDR Superior Izquierda: 389
# LDR Superior Derecha: 738
# LDR Inferior Izquierda: 889
# LDR Inferior Derecha: 267
# veg=570
# tol=50, dtime=50
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 472
# LDR Superior Derecha: 207
# LDR Inferior Izquierda: 736
# LDR Inferior Derecha: 444
# veg=464
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 806
# LDR Superior Derecha: 773
# LDR Inferior Izquierda: 714
# LDR Inferior Derecha: 686
# veg=744
# tol=50, dtime=50
# Vertical movido a 121°
#
# -----------------------------------
#
# LDR Superior Izquierda: 421
# LDR Superior Derecha: 399
# LDR Inferior Izquierda: 715
# LDR Inferior Derecha: 336
# veg=467
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 641
# LDR Superior Derecha: 606
# LDR Inferior Izquierda: 457
# LDR Inferior Derecha: 196
# veg=474
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 617
# LDR Superior Derecha: 848
# LDR Inferior Izquierda: 705
# LDR Inferior Derecha: 618
# veg=696
# tol=50, dtime=50
# Vertical movido a 122°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 753
# LDR Superior Derecha: 226
# LDR Inferior Izquierda: 742
# LDR Inferior Derecha: 450
# veg=542
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 414
# LDR Superior Derecha: 136
# LDR Inferior Izquierda: 602
# LDR Inferior Derecha: 720
# veg=468
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 96°
#
# -----------------------------------
#
# LDR Superior Izquierda: 316
# LDR Superior Derecha: 599
# LDR Inferior Izquierda: 178
# LDR Inferior Derecha: 705
# veg=449
# tol=50, dtime=50
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 851
# LDR Superior Derecha: 534
# LDR Inferior Izquierda: 671
# LDR Inferior Derecha: 557
# veg=653
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 96°
#
# -----------------------------------
#
# LDR Superior Izquierda: 196
# LDR Superior Derecha: 134
# LDR Inferior Izquierda: 452
# LDR Inferior Derecha: 888
# veg=417
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 425
# LDR Superior Derecha: 295
# LDR Inferior Izquierda: 262
# LDR Inferior Derecha: 585
# veg=391
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 796
# LDR Superior Derecha: 359
# LDR Inferior Izquierda: 673
# LDR Inferior Derecha: 700
# veg=631
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 625
# LDR Superior Derecha: 568
# LDR Inferior Izquierda: 713
# LDR Inferior Derecha: 111
# veg=504
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 96°
#
# -----------------------------------
#
# LDR Superior Izquierda: 255
# LDR Superior Derecha: 760
# LDR Inferior Izquierda: 444
# LDR Inferior Derecha: 612
# veg=517
# tol=50, dtime=50
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 224
# LDR Superior Derecha: 710
# LDR Inferior Izquierda: 334
# LDR Inferior Derecha: 288
# veg=389
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 746
# LDR Superior Derecha: 616
# LDR Inferior Izquierda: 849
# LDR Inferior Derecha: 727
# veg=734
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 729
# LDR Superior Derecha: 119
# LDR Inferior Izquierda: 257
# LDR Inferior Derecha: 731
# veg=459
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 96°
#
# -----------------------------------
#
# LDR Superior Izquierda: 136
# LDR Superior Derecha: 180
# LDR Inferior Izquierda: 535
# LDR Inferior Derecha: 816
# veg=416
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 734
# LDR Superior Derecha: 219
# LDR Inferior Izquierda: 607
# LDR Inferior Derecha: 571
# veg=532
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 96°
#
# -----------------------------------
#
# LDR Superior Izquierda: 222
# LDR Superior Derecha: 699
# LDR Inferior Izquierda: 788
# LDR Inferior Derecha: 755
# veg=615
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 174
# LDR Superior Derecha: 748
# LDR Inferior Izquierda: 365
# LDR Inferior Derecha: 864
# veg=537
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 172
# LDR Superior Derecha: 179
# LDR Inferior Izquierda: 529
# LDR Inferior Derecha: 300
# veg=294
# tol=98, dtime=51
# Vertical movido a 113°
# Horizontal movido a 95°
#
# -----------------------------------
#
# LDR Superior Izquierda: 823
# LDR Superior Derecha: 721
# LDR Inferior Izquierda: 144
# LDR Inferior Derecha: 512
# veg=549
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 94°
#
# -----------------------------------
#
# LDR Superior Izquierda: 522
# LDR Superior Derecha: 873
# LDR Inferior Izquierda: 605
# LDR Inferior Derecha: 627
# veg=656
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 93°
#
# -----------------------------------
#
# LDR Superior Izquierda: 594
# LDR Superior Derecha: 685
# LDR Inferior Izquierda: 124
# LDR Inferior Derecha: 792
# veg=548
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 92°
#
# -----------------------------------
#
# LDR Superior Izquierda: 482
# LDR Superior Derecha: 560
# LDR Inferior Izquierda: 224
# LDR Inferior Derecha: 649
# veg=478
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 91°
#
# -----------------------------------
#
# LDR Superior Izquierda: 198
# LDR Superior Derecha: 552
# LDR Inferior Izquierda: 157
# LDR Inferior Derecha: 339
# veg=311
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 90°
#
# -----------------------------------
#
# LDR Superior Izquierda: 428
# LDR Superior Derecha: 752
# LDR Inferior Izquierda: 665
# LDR Inferior Derecha: 675
# veg=629
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 89°
#
# -----------------------------------
#
# LDR Superior Izquierda: 298
# LDR Superior Derecha: 876
# LDR Inferior Izquierda: 525
# LDR Inferior Derecha: 581
# veg=569
# tol=50, dtime=50
# Horizontal movido a 88°
#
# -----------------------------------
#
# LDR Superior Izquierda: 345
# LDR Superior Derecha: 543
# LDR Inferior Izquierda: 671
# LDR Inferior Derecha: 802
# veg=590
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 87°
#
# -----------------------------------
#
# LDR Superior Izquierda: 163
# LDR Superior Derecha: 640
# LDR Inferior Izquierda: 406
# LDR Inferior Derecha: 543
# veg=437
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 86°
#
# -----------------------------------
#
# LDR Superior Izquierda: 484
# LDR Superior Derecha: 308
# LDR Inferior Izquierda: 304
# LDR Inferior Derecha: 785
# veg=470
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 85°
#
# -----------------------------------
#
# LDR Superior Izquierda: 225
# LDR Superior Derecha: 551
# LDR Inferior Izquierda: 198
# LDR Inferior Derecha: 728
# veg=425
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 84°
#
# -----------------------------------
#
# LDR Superior Izquierda: 709
# LDR Superior Derecha: 745
# LDR Inferior Izquierda: 155
# LDR Inferior Derecha: 713
# veg=580
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 83°
#
# -----------------------------------
#
# LDR Superior Izquierda: 645
# LDR Superior Derecha: 462
# LDR Inferior Izquierda: 417
# LDR Inferior Derecha: 801
# veg=581
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 82°
#
# -----------------------------------
#
# LDR Superior Izquierda: 700
# LDR Superior Derecha: 177
# LDR Inferior Izquierda: 118
# LDR Inferior Derecha: 719
# veg=428
# tol=50, dtime=50
#
# -----------------------------------
#
# LDR Superior Izquierda: 137
# LDR Superior Derecha: 885
# LDR Inferior Izquierda: 195
# LDR Inferior Derecha: 589
# veg=451
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 81°
#
# -----------------------------------
#
# LDR Superior Izquierda: 464
# LDR Superior Derecha: 599
# LDR Inferior Izquierda: 287
# LDR Inferior Derecha: 697
# veg=511
# tol=50, dtime=50
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 665
# LDR Superior Derecha: 582
# LDR Inferior Izquierda: 695
# LDR Inferior Derecha: 330
# veg=567
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 81°
#
# -----------------------------------
#
# LDR Superior Izquierda: 645
# LDR Superior Derecha: 878
# LDR Inferior Izquierda: 692
# LDR Inferior Derecha: 586
# veg=700
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 294
# LDR Superior Derecha: 857
# LDR Inferior Izquierda: 488
# LDR Inferior Derecha: 900
# veg=634
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 816
# LDR Superior Derecha: 223
# LDR Inferior Izquierda: 415
# LDR Inferior Derecha: 234
# veg=421
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 218
# LDR Superior Derecha: 343
# LDR Inferior Izquierda: 201
# LDR Inferior Derecha: 283
# veg=261
# tol=87, dtime=56
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 655
# LDR Superior Derecha: 893
# LDR Inferior Izquierda: 225
# LDR Inferior Derecha: 352
# veg=531
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 873
# LDR Superior Derecha: 814
# LDR Inferior Izquierda: 422
# LDR Inferior Derecha: 692
# veg=700
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 536
# LDR Superior Derecha: 297
# LDR Inferior Izquierda: 557
# LDR Inferior Derecha: 261
# veg=412
# tol=50, dtime=50
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 692
# LDR Superior Derecha: 308
# LDR Inferior Izquierda: 641
# LDR Inferior Derecha: 192
# veg=458
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 322
# LDR Superior Derecha: 723
# LDR Inferior Izquierda: 646
# LDR Inferior Derecha: 832
# veg=630
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 607
# LDR Superior Derecha: 659
# LDR Inferior Izquierda: 611
# LDR Inferior Derecha: 560
# veg=609
# tol=50, dtime=50
#
# -----------------------------------
#
# LDR Superior Izquierda: 549
# LDR Superior Derecha: 491
# LDR Inferior Izquierda: 755
# LDR Inferior Derecha: 728
# veg=630
# tol=50, dtime=50
# Vertical movido a 117°
#
# -----------------------------------
#
# LDR Superior Izquierda: 430
# LDR Superior Derecha: 847
# LDR Inferior Izquierda: 817
# LDR Inferior Derecha: 812
# veg=726
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 404
# LDR Superior Derecha: 191
# LDR Inferior Izquierda: 409
# LDR Inferior Derecha: 302
# veg=326
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 237
# LDR Superior Derecha: 811
# LDR Inferior Izquierda: 310
# LDR Inferior Derecha: 675
# veg=508
# tol=50, dtime=50
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 142
# LDR Superior Derecha: 566
# LDR Inferior Izquierda: 291
# LDR Inferior Derecha: 754
# veg=438
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 704
# LDR Superior Derecha: 389
# LDR Inferior Izquierda: 498
# LDR Inferior Derecha: 168
# veg=439
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 710
# LDR Superior Derecha: 524
# LDR Inferior Izquierda: 225
# LDR Inferior Derecha: 173
# veg=407
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 190
# LDR Superior Derecha: 325
# LDR Inferior Izquierda: 364
# LDR Inferior Derecha: 371
# veg=312
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 717
# LDR Superior Derecha: 282
# LDR Inferior Izquierda: 591
# LDR Inferior Derecha: 398
# veg=496
# tol=50, dtime=50
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 351
# LDR Superior Derecha: 441
# LDR Inferior Izquierda: 790
# LDR Inferior Derecha: 557
# veg=534
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 231
# LDR Superior Derecha: 201
# LDR Inferior Izquierda: 112
# LDR Inferior Derecha: 301
# veg=211
# tol=70, dtime=65
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 155
# LDR Superior Derecha: 363
# LDR Inferior Izquierda: 210
# LDR Inferior Derecha: 391
# veg=279
# tol=93, dtime=53
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 801
# LDR Superior Derecha: 278
# LDR Inferior Izquierda: 449
# LDR Inferior Derecha: 219
# veg=436
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 599
# LDR Superior Derecha: 400
# LDR Inferior Izquierda: 356
# LDR Inferior Derecha: 887
# veg=560
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 659
# LDR Superior Derecha: 324
# LDR Inferior Izquierda: 424
# LDR Inferior Derecha: 711
# veg=529
# tol=50, dtime=50
# Vertical movido a 113°
#
# -----------------------------------
#
# LDR Superior Izquierda: 885
# LDR Superior Derecha: 885
# LDR Inferior Izquierda: 524
# LDR Inferior Derecha: 415
# veg=677
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 194
# LDR Superior Derecha: 464
# LDR Inferior Izquierda: 609
# LDR Inferior Derecha: 144
# veg=352
# tol=50, dtime=50
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 387
# LDR Superior Derecha: 880
# LDR Inferior Izquierda: 492
# LDR Inferior Derecha: 724
# veg=620
# tol=50, dtime=50
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 202
# LDR Superior Derecha: 554
# LDR Inferior Izquierda: 135
# LDR Inferior Derecha: 188
# veg=269
# tol=89, dtime=55
# Vertical movido a 115°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 686
# LDR Superior Derecha: 808
# LDR Inferior Izquierda: 238
# LDR Inferior Derecha: 800
# veg=633
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 440
# LDR Superior Derecha: 231
# LDR Inferior Izquierda: 831
# LDR Inferior Derecha: 689
# veg=547
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 197
# LDR Superior Derecha: 336
# LDR Inferior Izquierda: 876
# LDR Inferior Derecha: 416
# veg=456
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 182
# LDR Superior Derecha: 207
# LDR Inferior Izquierda: 693
# LDR Inferior Derecha: 470
# veg=387
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 314
# LDR Superior Derecha: 681
# LDR Inferior Izquierda: 833
# LDR Inferior Derecha: 406
# veg=558
# tol=50, dtime=50
# Vertical movido a 112°
#
# -----------------------------------
#
# LDR Superior Izquierda: 729
# LDR Superior Derecha: 721
# LDR Inferior Izquierda: 745
# LDR Inferior Derecha: 563
# veg=689
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 288
# LDR Superior Derecha: 833
# LDR Inferior Izquierda: 779
# LDR Inferior Derecha: 890
# veg=697
# tol=50, dtime=50
# Vertical movido a 112°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 641
# LDR Superior Derecha: 833
# LDR Inferior Izquierda: 301
# LDR Inferior Derecha: 378
# veg=538
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 728
# LDR Superior Derecha: 574
# LDR Inferior Izquierda: 317
# LDR Inferior Derecha: 220
# veg=459
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 708
# LDR Superior Derecha: 131
# LDR Inferior Izquierda: 879
# LDR Inferior Derecha: 694
# veg=602
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 612
# LDR Superior Derecha: 610
# LDR Inferior Izquierda: 221
# LDR Inferior Derecha: 494
# veg=484
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 593
# LDR Superior Derecha: 624
# LDR Inferior Izquierda: 156
# LDR Inferior Derecha: 711
# veg=520
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 822
# LDR Superior Derecha: 876
# LDR Inferior Izquierda: 438
# LDR Inferior Derecha: 417
# veg=638
# tol=50, dtime=50
# Vertical movido a 116°
#
# -----------------------------------
#
# LDR Superior Izquierda: 310
# LDR Superior Derecha: 731
# LDR Inferior Izquierda: 638
# LDR Inferior Derecha: 535
# veg=553
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 801
# LDR Superior Derecha: 500
# LDR Inferior Izquierda: 452
# LDR Inferior Derecha: 788
# veg=635
# tol=50, dtime=50
#
# -----------------------------------
#
# LDR Superior Izquierda: 586
# LDR Superior Derecha: 386
# LDR Inferior Izquierda: 249
# LDR Inferior Derecha: 553
# veg=443
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 800
# LDR Superior Derecha: 433
# LDR Inferior Izquierda: 468
# LDR Inferior Derecha: 578
# veg=569
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 290
# LDR Superior Derecha: 452
# LDR Inferior Izquierda: 306
# LDR Inferior Derecha: 485
# veg=383
# tol=50, dtime=50
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 264
# LDR Superior Derecha: 208
# LDR Inferior Izquierda: 672
# LDR Inferior Derecha: 641
# veg=446
# tol=50, dtime=50
# Vertical movido a 116°
#
# -----------------------------------
#
# LDR Superior Izquierda: 826
# LDR Superior Derecha: 633
# LDR Inferior Izquierda: 557
# LDR Inferior Derecha: 818
# veg=708
# tol=50, dtime=50
#
# -----------------------------------
#
# LDR Superior Izquierda: 498
# LDR Superior Derecha: 566
# LDR Inferior Izquierda: 709
# LDR Inferior Derecha: 483
# veg=563
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 764
# LDR Superior Derecha: 660
# LDR Inferior Izquierda: 425
# LDR Inferior Derecha: 371
# veg=554
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 191
# LDR Superior Derecha: 107
# LDR Inferior Izquierda: 526
# LDR Inferior Derecha: 536
# veg=339
# tol=50, dtime=50
# Vertical movido a 115°
#
# -----------------------------------
#
# LDR Superior Izquierda: 774
# LDR Superior Derecha: 502
# LDR Inferior Izquierda: 333
# LDR Inferior Derecha: 551
# veg=539
# tol=50, dtime=50
# Vertical movido a 116°
#
# -----------------------------------
#
# LDR Superior Izquierda: 247
# LDR Superior Derecha: 100
# LDR Inferior Izquierda: 794
# LDR Inferior Derecha: 673
# veg=453
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 579
# LDR Superior Derecha: 461
# LDR Inferior Izquierda: 791
# LDR Inferior Derecha: 262
# veg=523
# tol=50, dtime=50
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 285
# LDR Superior Derecha: 394
# LDR Inferior Izquierda: 256
# LDR Inferior Derecha: 721
# veg=413
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 839
# LDR Superior Derecha: 493
# LDR Inferior Izquierda: 125
# LDR Inferior Derecha: 566
# veg=505
# tol=50, dtime=50
# Vertical movido a 115°
#
# -----------------------------------
#
# LDR Superior Izquierda: 464
# LDR Superior Derecha: 531
# LDR Inferior Izquierda: 385
# LDR Inferior Derecha: 669
# veg=512
# tol=50, dtime=50
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 420
# LDR Superior Derecha: 596
# LDR Inferior Izquierda: 520
# LDR Inferior Derecha: 651
# veg=546
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 644
# LDR Superior Derecha: 503
# LDR Inferior Izquierda: 525
# LDR Inferior Derecha: 679
# veg=587
# tol=50, dtime=50
#
# -----------------------------------
#
# LDR Superior Izquierda: 557
# LDR Superior Derecha: 810
# LDR Inferior Izquierda: 768
# LDR Inferior Derecha: 772
# veg=726
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 787
# LDR Superior Derecha: 853
# LDR Inferior Izquierda: 680
# LDR Inferior Derecha: 466
# veg=696
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 616
# LDR Superior Derecha: 512
# LDR Inferior Izquierda: 173
# LDR Inferior Derecha: 692
# veg=498
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 506
# LDR Superior Derecha: 418
# LDR Inferior Izquierda: 528
# LDR Inferior Derecha: 556
# veg=502
# tol=50, dtime=50
# Vertical movido a 114°
#
# -----------------------------------
#
# LDR Superior Izquierda: 684
# LDR Superior Derecha: 135
# LDR Inferior Izquierda: 772
# LDR Inferior Derecha: 420
# veg=502
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 740
# LDR Superior Derecha: 350
# LDR Inferior Izquierda: 594
# LDR Inferior Derecha: 450
# veg=533
# tol=50, dtime=50
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 233
# LDR Superior Derecha: 853
# LDR Inferior Izquierda: 286
# LDR Inferior Derecha: 696
# veg=516
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 444
# LDR Superior Derecha: 215
# LDR Inferior Izquierda: 360
# LDR Inferior Derecha: 449
# veg=366
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 468
# LDR Superior Derecha: 766
# LDR Inferior Izquierda: 187
# LDR Inferior Derecha: 752
# veg=543
# tol=50, dtime=50
# Vertical movido a 114°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 193
# LDR Superior Derecha: 224
# LDR Inferior Izquierda: 820
# LDR Inferior Derecha: 493
# veg=432
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 533
# LDR Superior Derecha: 661
# LDR Inferior Izquierda: 794
# LDR Inferior Derecha: 606
# veg=648
# tol=50, dtime=50
# Vertical movido a 112°
#
# -----------------------------------
#
# LDR Superior Izquierda: 127
# LDR Superior Derecha: 680
# LDR Inferior Izquierda: 122
# LDR Inferior Derecha: 657
# veg=396
# tol=50, dtime=50
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 882
# LDR Superior Derecha: 602
# LDR Inferior Izquierda: 269
# LDR Inferior Derecha: 893
# veg=661
# tol=50, dtime=50
# Vertical movido a 113°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 848
# LDR Superior Derecha: 866
# LDR Inferior Izquierda: 820
# LDR Inferior Derecha: 787
# veg=830
# tol=50, dtime=50
# Vertical movido a 114°
#
# -----------------------------------
#
# LDR Superior Izquierda: 866
# LDR Superior Derecha: 510
# LDR Inferior Izquierda: 278
# LDR Inferior Derecha: 288
# veg=485
# tol=50, dtime=50
# Vertical movido a 115°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 211
# LDR Superior Derecha: 772
# LDR Inferior Izquierda: 500
# LDR Inferior Derecha: 131
# veg=403
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 623
# LDR Superior Derecha: 139
# LDR Inferior Izquierda: 240
# LDR Inferior Derecha: 170
# veg=292
# tol=97, dtime=51
# Vertical movido a 117°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 439
# LDR Superior Derecha: 439
# LDR Inferior Izquierda: 613
# LDR Inferior Derecha: 195
# veg=421
# tol=50, dtime=50
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 328
# LDR Superior Derecha: 623
# LDR Inferior Izquierda: 641
# LDR Inferior Derecha: 115
# veg=426
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 131
# LDR Superior Derecha: 542
# LDR Inferior Izquierda: 141
# LDR Inferior Derecha: 215
# veg=257
# tol=85, dtime=57
# Vertical movido a 119°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 466
# LDR Superior Derecha: 127
# LDR Inferior Izquierda: 747
# LDR Inferior Derecha: 154
# veg=373
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 278
# LDR Superior Derecha: 885
# LDR Inferior Izquierda: 245
# LDR Inferior Derecha: 169
# veg=394
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 749
# LDR Superior Derecha: 534
# LDR Inferior Izquierda: 882
# LDR Inferior Derecha: 208
# veg=593
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 878
# LDR Superior Derecha: 639
# LDR Inferior Izquierda: 688
# LDR Inferior Derecha: 124
# veg=582
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 109
# LDR Superior Derecha: 645
# LDR Inferior Izquierda: 474
# LDR Inferior Derecha: 154
# veg=345
# tol=50, dtime=50
# Vertical movido a 122°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 878
# LDR Superior Derecha: 692
# LDR Inferior Izquierda: 586
# LDR Inferior Derecha: 726
# veg=720
# tol=50, dtime=50
# Vertical movido a 123°
#
# -----------------------------------
#
# LDR Superior Izquierda: 416
# LDR Superior Derecha: 733
# LDR Inferior Izquierda: 858
# LDR Inferior Derecha: 454
# veg=615
# tol=50, dtime=50
# Vertical movido a 122°
#
# -----------------------------------
#
# LDR Superior Izquierda: 571
# LDR Superior Derecha: 554
# LDR Inferior Izquierda: 348
# LDR Inferior Derecha: 872
# veg=586
# tol=50, dtime=50
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 245
# LDR Superior Derecha: 510
# LDR Inferior Izquierda: 867
# LDR Inferior Derecha: 243
# veg=466
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 107
# LDR Superior Derecha: 476
# LDR Inferior Izquierda: 161
# LDR Inferior Derecha: 881
# veg=406
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 457
# LDR Superior Derecha: 361
# LDR Inferior Izquierda: 116
# LDR Inferior Derecha: 336
# veg=317
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 394
# LDR Superior Derecha: 474
# LDR Inferior Izquierda: 690
# LDR Inferior Derecha: 354
# veg=478
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 168
# LDR Superior Derecha: 581
# LDR Inferior Izquierda: 898
# LDR Inferior Derecha: 200
# veg=461
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 406
# LDR Superior Derecha: 260
# LDR Inferior Izquierda: 876
# LDR Inferior Derecha: 795
# veg=584
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 370
# LDR Superior Derecha: 718
# LDR Inferior Izquierda: 307
# LDR Inferior Derecha: 648
# veg=510
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 399
# LDR Superior Derecha: 400
# LDR Inferior Izquierda: 502
# LDR Inferior Derecha: 620
# veg=480
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 236
# LDR Superior Derecha: 605
# LDR Inferior Izquierda: 518
# LDR Inferior Derecha: 472
# veg=457
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 786
# LDR Superior Derecha: 240
# LDR Inferior Izquierda: 553
# LDR Inferior Derecha: 122
# veg=425
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 233
# LDR Superior Derecha: 306
# LDR Inferior Izquierda: 826
# LDR Inferior Derecha: 476
# veg=460
# tol=50, dtime=50
# Vertical movido a 117°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 188
# LDR Superior Derecha: 863
# LDR Inferior Izquierda: 538
# LDR Inferior Derecha: 669
# veg=564
# tol=50, dtime=50
# Vertical movido a 116°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 749
# LDR Superior Derecha: 475
# LDR Inferior Izquierda: 786
# LDR Inferior Derecha: 515
# veg=631
# tol=50, dtime=50
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 387
# LDR Superior Derecha: 715
# LDR Inferior Izquierda: 399
# LDR Inferior Derecha: 122
# veg=405
# tol=50, dtime=50
# Vertical movido a 117°
#
# -----------------------------------
#
# LDR Superior Izquierda: 313
# LDR Superior Derecha: 885
# LDR Inferior Izquierda: 116
# LDR Inferior Derecha: 215
# veg=382
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 636
# LDR Superior Derecha: 589
# LDR Inferior Izquierda: 684
# LDR Inferior Derecha: 505
# veg=603
# tol=50, dtime=50
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 713
# LDR Superior Derecha: 843
# LDR Inferior Izquierda: 379
# LDR Inferior Derecha: 892
# veg=706
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 450
# LDR Superior Derecha: 220
# LDR Inferior Izquierda: 826
# LDR Inferior Derecha: 689
# veg=546
# tol=50, dtime=50
# Vertical movido a 118°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 157
# LDR Superior Derecha: 542
# LDR Inferior Izquierda: 341
# LDR Inferior Derecha: 174
# veg=303
# tol=50, dtime=50
# Vertical movido a 119°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 567
# LDR Superior Derecha: 478
# LDR Inferior Izquierda: 528
# LDR Inferior Derecha: 492
# veg=516
# tol=50, dtime=50
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 545
# LDR Superior Derecha: 276
# LDR Inferior Izquierda: 130
# LDR Inferior Derecha: 175
# veg=281
# tol=93, dtime=53
# Vertical movido a 120°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 448
# LDR Superior Derecha: 538
# LDR Inferior Izquierda: 141
# LDR Inferior Derecha: 602
# veg=432
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 228
# LDR Superior Derecha: 786
# LDR Inferior Izquierda: 377
# LDR Inferior Derecha: 797
# veg=546
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 608
# LDR Superior Derecha: 548
# LDR Inferior Izquierda: 781
# LDR Inferior Derecha: 857
# veg=698
# tol=50, dtime=50
# Vertical movido a 119°
#
# -----------------------------------
#
# LDR Superior Izquierda: 169
# LDR Superior Derecha: 900
# LDR Inferior Izquierda: 232
# LDR Inferior Derecha: 102
# veg=350
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 536
# LDR Superior Derecha: 603
# LDR Inferior Izquierda: 426
# LDR Inferior Derecha: 393
# veg=489
# tol=50, dtime=50
# Vertical movido a 121°
#
# -----------------------------------
#
# LDR Superior Izquierda: 614
# LDR Superior Derecha: 636
# LDR Inferior Izquierda: 265
# LDR Inferior Derecha: 864
# veg=594
# tol=50, dtime=50
# Vertical movido a 122°
# Horizontal movido a 76°
#
# -----------------------------------
#
# LDR Superior Izquierda: 366
# LDR Superior Derecha: 181
# LDR Inferior Izquierda: 291
# LDR Inferior Derecha: 205
# veg=260
# tol=86, dtime=56
# Horizontal movido a 77°
#
# -----------------------------------
#
# LDR Superior Izquierda: 330
# LDR Superior Derecha: 115
# LDR Inferior Izquierda: 581
# LDR Inferior Derecha: 695
# veg=430
# tol=50, dtime=50
# Vertical movido a 121°
#
# -----------------------------------
#
# LDR Superior Izquierda: 528
# LDR Superior Derecha: 120
# LDR Inferior Izquierda: 719
# LDR Inferior Derecha: 452
# veg=454
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 78°
#
# -----------------------------------
#
# LDR Superior Izquierda: 731
# LDR Superior Derecha: 333
# LDR Inferior Izquierda: 538
# LDR Inferior Derecha: 115
# veg=429
# tol=50, dtime=50
# Vertical movido a 121°
# Horizontal movido a 79°
#
# -----------------------------------
#
# LDR Superior Izquierda: 450
# LDR Superior Derecha: 109
# LDR Inferior Izquierda: 798
# LDR Inferior Derecha: 857
# veg=553
# tol=50, dtime=50
# Vertical movido a 120°
# Horizontal movido a 80°
#
# -----------------------------------
#
# LDR Superior Izquierda: 591
# LDR Superior Derecha: 629
# LDR Inferior Izquierda: 181
# LDR Inferior Derecha: 227
# veg=407
# tol=50, dtime=50
# Vertical movido a 121°
#
# -----------------------------------
